# %%
import pandas as pd

# %%
# %load_ext autoreload
import sys
sys.path.append('../..')

# %%
from faces_clustering import VideoClustering
# Out:
# Using TensorFlow backend.

# %%
video_clustering = VideoClustering('senet50', 'agglomerative')

# %%
embs = video_clustering.cluster('/home/paulo/Documentos/testes/starwars.mp4',fps=0.1)
# Out:
# extracting frames
# Frames already extracted.
# extracting embeddings
# ...
# clustering
# Best cluster number is 6

# %%
video_clustering.display_timeline(limit = 10, lines = True)

# %%
meta1 = video_clustering.video_metadata[['embeddings', 'frames', 'total_frames', 'video']]

# %%
embs2 = video_clustering.cluster('/home/paulo/Documentos/testes/bolso_daciolo.mp4',fps=0.1)
# Out:
# extracting frames
# Frames already extracted.
# extracting embeddings
# ...
# clustering
# Best cluster number is 2

# %%
video_clustering.display_timeline(limit = 10, lines = True)

# %%
meta2 = video_clustering.video_metadata[['embeddings', 'frames', 'total_frames', 'video']]

# %%
meta2
# Out:
#                                                               embeddings  \
# cluster_agglomerative
# 0                      [0.0090098223539398, 0.22567502485916896, 0.04...
# 1                      [0.014043213799595833, 8.96461636679513, 0.027...
#
#                                                                   frames  \
# cluster_agglomerative
# 0                      [2100, 300, 5700, 2400, 900, 1500, 5400, 600, ...
# 1                               [300, 5100, 4200, 4500, 600, 4800, 3900]
#
#                        total_frames  \
# cluster_agglomerative
# 0                                22
# 1                                22
#
#                                                                  video
# cluster_agglomerative
# 0                      /home/paulo/Documentos/testes/bolso_daciolo.mp4
# 1                      /home/paulo/Documentos/testes/bolso_daciolo.mp4
