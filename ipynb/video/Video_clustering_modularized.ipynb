# %%
import pandas as pd

# %%
# %load_ext autoreload
import sys
sys.path.append('../..')

# %%
from faces_clustering import VideoClustering
# Out:
# Using TensorFlow backend.

# %%
video_clustering = VideoClustering('senet50', 'agglomerative')

# %%
embs = video_clustering.cluster('/home/paulo/Documentos/starwars.mp4', dir_path = '/home/paulo/Documentos/teste',fps=0.1)
# Out:
# extracting frames
# Frames already extracted.
# extracting embeddings
# HBox(children=(FloatProgress(value=0.0, max=62.0), HTML(value='')))
# clustering
# Best cluster number is 6

# %%
video_clustering.display_timeline(limit = 10, lines = True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
video_clustering.video_metadata[['embeddings', 'frames', 'total_frames', 'video']]
# Out:
#                                                               embeddings  \
# cluster_agglomerative
# 0                      [0.5974979845806956, 3.5082061752676963, 1.132...
# 1                      [0.21184267970319423, 3.012671281894048, 2.353...
# 2                      [0.05581708668198969, 8.228659206912631, 0.079...
# 3                      [0.10487441120751421, 4.873502375448451, 0.115...
# 4                      [1.1350668343630703, 2.6353480599143286, 0.141...
# 5                      [0.17320501506328584, 4.574567747116089, 2.379...
#
#                                                                   frames  \
# cluster_agglomerative
# 0                      [13680, 9360, 5760, 2160, 480, 6240, 6480, 144...
# 1                      [13200, 5040, 4560, 8880, 2400, 1920, 7680, 28...
# 2                      [13680, 9360, 5760, 2160, 480, 6240, 6480, 144...
# 3                      [13200, 5040, 4560, 8880, 2400, 1920, 7680, 28...
# 4                      [10800, 7200, 11280, 3600, 7440, 3360, 12000, ...
# 5                      [7200, 11280, 3600, 7440, 3360, 12000, 6960, 6...
#
#                        total_frames                                video
# cluster_agglomerative
# 0                                62  /home/paulo/Documentos/starwars.mp4
# 1                                62  /home/paulo/Documentos/starwars.mp4
# 2                                62  /home/paulo/Documentos/starwars.mp4
# 3                                62  /home/paulo/Documentos/starwars.mp4
# 4                                62  /home/paulo/Documentos/starwars.mp4
# 5                                62  /home/paulo/Documentos/starwars.mp4
