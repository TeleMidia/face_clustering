# %%
import pandas as pd
import matplotlib as plt

# %%
df_r = pd.read_csv('../../results/test_clusters.csv', index_col=0)
df_r
# Out:
#        Any_Cluster  Mode Equal to Class  Class is present in cluster  \
# alpha
# 2         1.000000             0.949318                     0.982456
# 3         0.970760             0.941520                     0.968811
# 4         0.955166             0.931774                     0.953216
# 5         0.945419             0.923977                     0.943470
# 6         0.935673             0.918129                     0.933723
# 7         0.927875             0.912281                     0.925926
# 8         0.918129             0.906433                     0.916179
# 9         0.904483             0.892788                     0.902534
# 10        0.894737             0.883041                     0.892788
#
#        lfw assigned to no cluster
# alpha
# 2                        0.000000
# 3                        0.945419
# 4                        0.986355
# 5                        0.992203
# 6                        0.996101
# 7                        0.998051
# ...

# %%
df_s = pd.read_csv('../../results/test_clusters_silhouette.csv', index_col=0)
df_s
# Out:
#        Any_Cluster  Mode Equal to Class  Class is present in cluster  \
# alpha
# 2         1.000000             0.931774                     0.943470
# 3         0.863548             0.855750                     0.861598
# 4         0.769981             0.766082                     0.769981
# 5         0.729045             0.725146                     0.729045
# 6         0.688109             0.684211                     0.688109
# 7         0.649123             0.645224                     0.649123
# 8         0.612086             0.608187                     0.612086
# 9         0.600390             0.596491                     0.600390
# 10        0.582846             0.578947                     0.582846
#
#        lfw assigned to no cluster
# alpha
# 2                        0.000000
# 3                        0.982456
# 4                        0.994152
# 5                        0.998051
# 6                        1.000000
# 7                        1.000000
# ...

# %%
df_r.plot()
